# %%
import pandas as pd
import numpy as np
from sklearn import linear_model, datasets, metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
housing = datasets.fetch_california_housing()

# %%
x = housing.data

# %%
y = housing.target

# %%
print(x.shape)
print(y.shape)
# Out:
# (20640, 8)
# (20640,)

# %%
l_reg = linear_model.LinearRegression()

# %%
plt.scatter(x.T[6], y)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (16512, 8)
# (16512,)

# %%
model = l_reg.fit(X_train, y_train)

# %%
predictions = model.predict(X_test)

# %%
print(predictions)
# Out:
# [0.64594246 2.14615017 2.98231346 ... 2.13026182 1.22033904 2.02551193]

# %%
print('R^6:{}'.format(l_reg.score(x, y)))
# Out:
# R^6:0.6061072376807171

# %%
print(l_reg.coef_)
# Out:
# [ 4.30287181e-01  9.22527540e-03 -1.00178785e-01  5.92848517e-01
#  -5.35186423e-06 -3.84080557e-03 -4.19661187e-01 -4.31870127e-01]

# %%
print(l_reg.intercept_)
# Out:
# -36.634224872486584
